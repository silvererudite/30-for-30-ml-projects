# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/emojiimage-dataset/full_emoji.csv
# /kaggle/input/emojiimage-dataset/image/Windows/1231.png
# /kaggle/input/emojiimage-dataset/image/Windows/1017.png
# /kaggle/input/emojiimage-dataset/image/Windows/1522.png
# /kaggle/input/emojiimage-dataset/image/Windows/641.png
# /kaggle/input/emojiimage-dataset/image/Windows/1088.png
# /kaggle/input/emojiimage-dataset/image/Windows/173.png
# /kaggle/input/emojiimage-dataset/image/Windows/1479.png
# /kaggle/input/emojiimage-dataset/image/Windows/815.png
# /kaggle/input/emojiimage-dataset/image/Windows/491.png
# /kaggle/input/emojiimage-dataset/image/Windows/1457.png
# /kaggle/input/emojiimage-dataset/image/Windows/1084.png
# /kaggle/input/emojiimage-dataset/image/Windows/718.png
# /kaggle/input/emojiimage-dataset/image/Windows/709.png
# /kaggle/input/emojiimage-dataset/image/Windows/889.png
# /kaggle/input/emojiimage-dataset/image/Windows/379.png
# /kaggle/input/emojiimage-dataset/image/Windows/780.png
# /kaggle/input/emojiimage-dataset/image/Windows/248.png
# /kaggle/input/emojiimage-dataset/image/Windows/94.png
# /kaggle/input/emojiimage-dataset/image/Windows/480.png
# /kaggle/input/emojiimage-dataset/image/Windows/1145.png
# /kaggle/input/emojiimage-dataset/image/Windows/236.png
# /kaggle/input/emojiimage-dataset/image/Windows/1012.png
# /kaggle/input/emojiimage-dataset/image/Windows/1343.png
# /kaggle/input/emojiimage-dataset/image/Windows/771.png
# /kaggle/input/emojiimage-dataset/image/Windows/340.png
# /kaggle/input/emojiimage-dataset/image/Windows/48.png
# /kaggle/input/emojiimage-dataset/image/Windows/513.png
# /kaggle/input/emojiimage-dataset/image/Windows/1037.png
# /kaggle/input/emojiimage-dataset/image/Windows/677.png
# /kaggle/input/emojiimage-dataset/image/Windows/350.png
# /kaggle/input/emojiimage-dataset/image/Windows/761.png
# /kaggle/input/emojiimage-dataset/image/Windows/1258.png
# /kaggle/input/emojiimage-dataset/image/Windows/314.png
# /kaggle/input/emojiimage-dataset/image/Windows/1023.png
# /kaggle/input/emojiimage-dataset/image/Windows/1337.png
# /kaggle/input/emojiimage-dataset/image/Windows/655.png
# /kaggle/input/emojiimage-dataset/image/Windows/227.png
# /kaggle/input/emojiimage-dataset/image/Windows/762.png
# /kaggle/input/emojiimage-dataset/image/Windows/726.png
# /kaggle/input/emojiimage-dataset/image/Windows/238.png
# /kaggle/input/emojiimage-dataset/image/Windows/61.png
# /kaggle/input/emojiimage-dataset/image/Windows/377.png
# /kaggle/input/emojiimage-dataset/image/Windows/581.png
# /kaggle/input/emojiimage-dataset/image/Windows/222.png
# /kaggle/input/emojiimage-dataset/image/Windows/330.png
# /kaggle/input/emojiimage-dataset/image/Windows/511.png
# /kaggle/input/emojiimage-dataset/image/Windows/579.png
# /kaggle/input/emojiimage-dataset/image/Windows/927.png
# /kaggle/input/emojiimage-dataset/image/Windows/303.png
# /kaggle/input/emojiimage-dataset/image/Windows/37.png
# /kaggle/input/emojiimage-dataset/image/Windows/231.png
# /kaggle/input/emojiimage-dataset/image/Windows/1048.png
# /kaggle/input/emojiimage-dataset/image/Windows/645.png
# /kaggle/input/emojiimage-dataset/image/Windows/449.png
# /kaggle/input/emojiimage-dataset/image/Windows/353.png
# /kaggle/input/emojiimage-dataset/image/Windows/621.png
# /kaggle/input/emojiimage-dataset/image/Windows/148.png
# /kaggle/input/emojiimage-dataset/image/Windows/990.png
# /kaggle/input/emojiimage-dataset/image/Windows/403.png
# /kaggle/input/emojiimage-dataset/image/Windows/1000.png
# /kaggle/input/emojiimage-dataset/image/Windows/352.png
# /kaggle/input/emojiimage-dataset/image/Windows/35.png
# /kaggle/input/emojiimage-dataset/image/Windows/232.png
# /kaggle/input/emojiimage-dataset/image/Windows/817.png
# /kaggle/input/emojiimage-dataset/image/Windows/334.png
# /kaggle/input/emojiimage-dataset/image/Windows/177.png
# /kaggle/input/emojiimage-dataset/image/Windows/1081.png
# /kaggle/input/emojiimage-dataset/image/Windows/142.png
# /kaggle/input/emojiimage-dataset/image/Windows/834.png
# /kaggle/input/emojiimage-dataset/image/Windows/1176.png
# /kaggle/input/emojiimage-dataset/image/Windows/754.png
# /kaggle/input/emojiimage-dataset/image/Windows/407.png
# /kaggle/input/emojiimage-dataset/image/Windows/104.png
# /kaggle/input/emojiimage-dataset/image/Windows/1413.png
# /kaggle/input/emojiimage-dataset/image/Windows/384.png
# /kaggle/input/emojiimage-dataset/image/Windows/376.png
# /kaggle/input/emojiimage-dataset/image/Windows/543.png
# /kaggle/input/emojiimage-dataset/image/Windows/1312.png
# /kaggle/input/emojiimage-dataset/image/Windows/737.png
# /kaggle/input/emojiimage-dataset/image/Windows/1156.png
# /kaggle/input/emojiimage-dataset/image/Windows/1004.png
# /kaggle/input/emojiimage-dataset/image/Windows/133.png
# /kaggle/input/emojiimage-dataset/image/Windows/70.png
# /kaggle/input/emojiimage-dataset/image/Windows/1529.png
# /kaggle/input/emojiimage-dataset/image/Windows/162.png
# /kaggle/input/emojiimage-dataset/image/Windows/419.png
# /kaggle/input/emojiimage-dataset/image/Windows/951.png
# /kaggle/input/emojiimage-dataset/image/Windows/940.png
# /kaggle/input/emojiimage-dataset/image/Windows/517.png
# /kaggle/input/emojiimage-dataset/image/Windows/1032.png
# /kaggle/input/emojiimage-dataset/image/Windows/398.png
# /kaggle/input/emojiimage-dataset/image/Windows/634.png
# /kaggle/input/emojiimage-dataset/image/Windows/1513.png
# /kaggle/input/emojiimage-dataset/image/Windows/186.png
# /kaggle/input/emojiimage-dataset/image/Windows/778.png
# /kaggle/input/emojiimage-dataset/image/Windows/73.png
# /kaggle/input/emojiimage-dataset/image/Windows/870.png
# /kaggle/input/emojiimage-dataset/image/Windows/933.png
# /kaggle/input/emojiimage-dataset/image/Windows/92.png
# /kaggle/input/emojiimage-dataset/image/Windows/1328.png
# /kaggle/input/emojiimage-dataset/image/Windows/542.png
# /kaggle/input/emojiimage-dataset/image/Windows/766.png
# /kaggle/input/emojiimage-dataset/image/Windows/315.png
# /kaggle/input/emojiimage-dataset/image/Windows/436.png
# /kaggle/input/emojiimage-dataset/image/Windows/359.png
# /kaggle/input/emojiimage-dataset/image/Windows/261.png
# /kaggle/input/emojiimage-dataset/image/Windows/1214.png
# /kaggle/input/emojiimage-dataset/image/Windows/1532.png
# /kaggle/input/emojiimage-dataset/image/Windows/901.png
# /kaggle/input/emojiimage-dataset/image/Windows/1096.png
# /kaggle/input/emojiimage-dataset/image/Windows/153.png
# /kaggle/input/emojiimage-dataset/image/Windows/1500.png
# /kaggle/input/emojiimage-dataset/image/Windows/1320.png
# /kaggle/input/emojiimage-dataset/image/Windows/167.png
# /kaggle/input/emojiimage-dataset/image/Windows/1348.png
# /kaggle/input/emojiimage-dataset/image/Windows/628.png
# /kaggle/input/emojiimage-dataset/image/Windows/506.png
# /kaggle/input/emojiimage-dataset/image/Windows/1147.png
# /kaggle/input/emojiimage-dataset/image/Windows/1375.png
# /kaggle/input/emojiimage-dataset/image/Windows/1452.png
# /kaggle/input/emojiimage-dataset/image/Windows/441.png
# /kaggle/input/emojiimage-dataset/image/Windows/928.png
# /kaggle/input/emojiimage-dataset/image/Windows/562.png
# /kaggle/input/emojiimage-dataset/image/Windows/681.png
# /kaggle/input/emojiimage-dataset/image/Windows/1266.png
# /kaggle/input/emojiimage-dataset/image/Windows/1542.png
# /kaggle/input/emojiimage-dataset/image/Windows/1206.png
# /kaggle/input/emojiimage-dataset/image/Windows/1064.png
# /kaggle/input/emojiimage-dataset/image/Windows/204.png
# /kaggle/input/emojiimage-dataset/image/Windows/646.png
# /kaggle/input/emojiimage-dataset/image/Windows/1179.png
# /kaggle/input/emojiimage-dataset/image/Windows/75.png
# /kaggle/input/emojiimage-dataset/image/Windows/1128.png
# /kaggle/input/emojiimage-dataset/image/Windows/1494.png
# /kaggle/input/emojiimage-dataset/image/Windows/1364.png
# /kaggle/input/emojiimage-dataset/image/Windows/1334.png
# /kaggle/input/emojiimage-dataset/image/Windows/1072.png
# /kaggle/input/emojiimage-dataset/image/Windows/1123.png
# /kaggle/input/emojiimage-dataset/image/Windows/744.png
# /kaggle/input/emojiimage-dataset/image/Windows/1314.png
# /kaggle/input/emojiimage-dataset/image/Windows/538.png
# /kaggle/input/emojiimage-dataset/image/Windows/651.png
# /kaggle/input/emojiimage-dataset/image/Windows/899.png
# /kaggle/input/emojiimage-dataset/image/Windows/270.png
# /kaggle/input/emojiimage-dataset/image/Windows/89.png
# /kaggle/input/emojiimage-dataset/image/Windows/385.png
# /kaggle/input/emojiimage-dataset/image/Windows/768.png
# /kaggle/input/emojiimage-dataset/image/Windows/872.png
# /kaggle/input/emojiimage-dataset/image/Windows/333.png
# /kaggle/input/emojiimage-dataset/image/Windows/164.png
# /kaggle/input/emojiimage-dataset/image/Windows/1168.png
# /kaggle/input/emojiimage-dataset/image/Windows/1118.png
# /kaggle/input/emojiimage-dataset/image/Windows/752.png
# /kaggle/input/emojiimage-dataset/image/Windows/550.png
# /kaggle/input/emojiimage-dataset/image/Windows/1326.png
# /kaggle/input/emojiimage-dataset/image/Windows/521.png
# /kaggle/input/emojiimage-dataset/image/Windows/1275.png
# /kaggle/input/emojiimage-dataset/image/Windows/11.png
# /kaggle/input/emojiimage-dataset/image/Windows/1036.png
# /kaggle/input/emojiimage-dataset/image/Windows/615.png
# /kaggle/input/emojiimage-dataset/image/Windows/416.png
# /kaggle/input/emojiimage-dataset/image/Windows/994.png
# /kaggle/input/emojiimage-dataset/image/Windows/881.png
# /kaggle/input/emojiimage-dataset/image/Windows/605.png
# /kaggle/input/emojiimage-dataset/image/Windows/707.png
# /kaggle/input/emojiimage-dataset/image/Windows/351.png
# /kaggle/input/emojiimage-dataset/image/Windows/1010.png
# /kaggle/input/emojiimage-dataset/image/Windows/1208.png
# /kaggle/input/emojiimage-dataset/image/Windows/213.png
# /kaggle/input/emojiimage-dataset/image/Windows/411.png
# /kaggle/input/emojiimage-dataset/image/Windows/505.png
# /kaggle/input/emojiimage-dataset/image/Windows/1445.png
# /kaggle/input/emojiimage-dataset/image/Windows/114.png
# /kaggle/input/emojiimage-dataset/image/Windows/1307.png
# /kaggle/input/emojiimage-dataset/image/Windows/930.png
# /kaggle/input/emojiimage-dataset/image/Windows/185.png
# /kaggle/input/emojiimage-dataset/image/Windows/240.png
# /kaggle/input/emojiimage-dataset/image/Windows/1483.png
# /kaggle/input/emojiimage-dataset/image/Windows/811.png
# /kaggle/input/emojiimage-dataset/image/Windows/317.png
# /kaggle/input/emojiimage-dataset/image/Windows/1294.png
# /kaggle/input/emojiimage-dataset/image/Windows/1530.png
# /kaggle/input/emojiimage-dataset/image/Windows/1514.png
# /kaggle/input/emojiimage-dataset/image/Windows/1041.png
# /kaggle/input/emojiimage-dataset/image/Windows/1268.png
# /kaggle/input/emojiimage-dataset/image/Windows/457.png
# /kaggle/input/emojiimage-dataset/image/Windows/493.png
# /kaggle/input/emojiimage-dataset/image/Windows/1329.png
# /kaggle/input/emojiimage-dataset/image/Windows/759.png
# /kaggle/input/emojiimage-dataset/image/Windows/907.png
# /kaggle/input/emojiimage-dataset/image/Windows/1071.png
# /kaggle/input/emojiimage-dataset/image/Windows/362.png
# /kaggle/input/emojiimage-dataset/image/Windows/1148.png
# /kaggle/input/emojiimage-dataset/image/Windows/176.png
# /kaggle/input/emojiimage-dataset/image/Windows/660.png
# /kaggle/input/emojiimage-dataset/image/Windows/727.png
# /kaggle/input/emojiimage-dataset/image/Windows/95.png
# /kaggle/input/emojiimage-dataset/image/Windows/432.png
# /kaggle/input/emojiimage-dataset/image/Windows/895.png
# /kaggle/input/emojiimage-dataset/image/Windows/1161.png
# /kaggle/input/emojiimage-dataset/image/Windows/97.png
# /kaggle/input/emojiimage-dataset/image/Windows/1351.png
# /kaggle/input/emojiimage-dataset/image/Windows/124.png
# /kaggle/input/emojiimage-dataset/image/Windows/119.png
# /kaggle/input/emojiimage-dataset/image/Windows/1227.png
# /kaggle/input/emojiimage-dataset/image/Windows/791.png
# /kaggle/input/emojiimage-dataset/image/Windows/654.png
# /kaggle/input/emojiimage-dataset/image/Windows/100.png
# /kaggle/input/emojiimage-dataset/image/Windows/1381.png
# /kaggle/input/emojiimage-dataset/image/Windows/211.png
# /kaggle/input/emojiimage-dataset/image/Windows/1241.png
# /kaggle/input/emojiimage-dataset/image/Windows/500.png
# /kaggle/input/emojiimage-dataset/image/Windows/322.png
# /kaggle/input/emojiimage-dataset/image/Windows/76.png
# /kaggle/input/emojiimage-dataset/image/Windows/1197.png
# /kaggle/input/emojiimage-dataset/image/Windows/193.png
# /kaggle/input/emojiimage-dataset/image/Windows/608.png
# /kaggle/input/emojiimage-dataset/image/Windows/191.png
# /kaggle/input/emojiimage-dataset/image/Windows/420.png
# /kaggle/input/emojiimage-dataset/image/Windows/528.png
# /kaggle/input/emojiimage-dataset/image/Windows/31.png
# /kaggle/input/emojiimage-dataset/image/Windows/623.png
# /kaggle/input/emojiimage-dataset/image/Windows/969.png
# /kaggle/input/emojiimage-dataset/image/Windows/1097.png
# /kaggle/input/emojiimage-dataset/image/Windows/642.png
# /kaggle/input/emojiimage-dataset/image/Windows/1401.png
# /kaggle/input/emojiimage-dataset/image/Windows/825.png
# /kaggle/input/emojiimage-dataset/image/Windows/1420.png
# /kaggle/input/emojiimage-dataset/image/Windows/1122.png
# /kaggle/input/emojiimage-dataset/image/Windows/1018.png
# /kaggle/input/emojiimage-dataset/image/Windows/1220.png
# /kaggle/input/emojiimage-dataset/image/Windows/1469.png
# /kaggle/input/emojiimage-dataset/image/Windows/138.png
# /kaggle/input/emojiimage-dataset/image/Windows/629.png
# /kaggle/input/emojiimage-dataset/image/Windows/1333.png
# /kaggle/input/emojiimage-dataset/image/Windows/396.png
# /kaggle/input/emojiimage-dataset/image/Windows/4.png
# /kaggle/input/emojiimage-dataset/image/Windows/1405.png
# /kaggle/input/emojiimage-dataset/image/Windows/796.png
# /kaggle/input/emojiimage-dataset/image/Windows/844.png
# /kaggle/input/emojiimage-dataset/image/Windows/225.png
# /kaggle/input/emojiimage-dataset/image/Windows/1371.png
# /kaggle/input/emojiimage-dataset/image/Windows/492.png
# /kaggle/input/emojiimage-dataset/image/Windows/669.png
# /kaggle/input/emojiimage-dataset/image/Windows/1315.png
# /kaggle/input/emojiimage-dataset/image/Windows/1219.png
# /kaggle/input/emojiimage-dataset/image/Windows/1482.png
# /kaggle/input/emojiimage-dataset/image/Windows/192.png
# /kaggle/input/emojiimage-dataset/image/Windows/1249.png
# /kaggle/input/emojiimage-dataset/image/Windows/43.png
# /kaggle/input/emojiimage-dataset/image/Windows/1137.png
# /kaggle/input/emojiimage-dataset/image/Windows/229.png
# /kaggle/input/emojiimage-dataset/image/Windows/992.png
# /kaggle/input/emojiimage-dataset/image/Windows/635.png
# /kaggle/input/emojiimage-dataset/image/Windows/1135.png
# /kaggle/input/emojiimage-dataset/image/Windows/962.png
# /kaggle/input/emojiimage-dataset/image/Windows/129.png
# /kaggle/input/emojiimage-dataset/image/Windows/331.png
# /kaggle/input/emojiimage-dataset/image/Windows/1243.png
# /kaggle/input/emojiimage-dataset/image/Windows/1067.png
# /kaggle/input/emojiimage-dataset/image/Windows/313.png
# /kaggle/input/emojiimage-dataset/image/Windows/966.png
# /kaggle/input/emojiimage-dataset/image/Windows/672.png
# /kaggle/input/emojiimage-dataset/image/Windows/820.png
# /kaggle/input/emojiimage-dataset/image/Windows/1349.png
# /kaggle/input/emojiimage-dataset/image/Windows/1279.png
# /kaggle/input/emojiimage-dataset/image/Windows/580.png
# /kaggle/input/emojiimage-dataset/image/Windows/345.png
# /kaggle/input/emojiimage-dataset/image/Windows/171.png
# /kaggle/input/emojiimage-dataset/image/Windows/682.png
# /kaggle/input/emojiimage-dataset/image/Windows/1113.png
# /kaggle/input/emojiimage-dataset/image/Windows/903.png
# /kaggle/input/emojiimage-dataset/image/Windows/1154.png
# /kaggle/input/emojiimage-dataset/image/Windows/1339.png
# /kaggle/input/emojiimage-dataset/image/Windows/1187.png
# /kaggle/input/emojiimage-dataset/image/Windows/1199.png
# /kaggle/input/emojiimage-dataset/image/Windows/324.png
# /kaggle/input/emojiimage-dataset/image/Windows/145.png
# /kaggle/input/emojiimage-dataset/image/Windows/1255.png
# /kaggle/input/emojiimage-dataset/image/Windows/863.png
# /kaggle/input/emojiimage-dataset/image/Windows/1283.png
# /kaggle/input/emojiimage-dataset/image/Windows/1108.png
# /kaggle/input/emojiimage-dataset/image/Windows/1430.png
# /kaggle/input/emojiimage-dataset/image/Windows/1548.png
# /kaggle/input/emojiimage-dataset/image/Windows/40.png
# /kaggle/input/emojiimage-dataset/image/Windows/1322.png
# /kaggle/input/emojiimage-dataset/image/Windows/1528.png
# /kaggle/input/emojiimage-dataset/image/Windows/209.png
# /kaggle/input/emojiimage-dataset/image/Windows/197.png
# /kaggle/input/emojiimage-dataset/image/Windows/1240.png
# /kaggle/input/emojiimage-dataset/image/Windows/1130.png
# /kaggle/input/emojiimage-dataset/image/Windows/982.png
# /kaggle/input/emojiimage-dataset/image/Windows/1507.png
# /kaggle/input/emojiimage-dataset/image/Windows/445.png
# /kaggle/input/emojiimage-dataset/image/Windows/1006.png
# /kaggle/input/emojiimage-dataset/image/Windows/575.png
# /kaggle/input/emojiimage-dataset/image/Windows/1347.png
# /kaggle/input/emojiimage-dataset/image/Windows/959.png
# /kaggle/input/emojiimage-dataset/image/Windows/33.png
# /kaggle/input/emojiimage-dataset/image/Windows/126.png
# /kaggle/input/emojiimage-dataset/image/Windows/876.png
# /kaggle/input/emojiimage-dataset/image/Windows/147.png
# /kaggle/input/emojiimage-dataset/image/Windows/973.png
# /kaggle/input/emojiimage-dataset/image/Windows/688.png
# /kaggle/input/emojiimage-dataset/image/Windows/1212.png
# /kaggle/input/emojiimage-dataset/image/Windows/1165.png
# /kaggle/input/emojiimage-dataset/image/Windows/468.png
# /kaggle/input/emojiimage-dataset/image/Windows/326.png
# /kaggle/input/emojiimage-dataset/image/Windows/357.png
# /kaggle/input/emojiimage-dataset/image/Windows/1361.png
# /kaggle/input/emojiimage-dataset/image/Windows/85.png
# /kaggle/input/emojiimage-dataset/image/Windows/9.png
# /kaggle/input/emojiimage-dataset/image/Windows/1045.png
# /kaggle/input/emojiimage-dataset/image/Windows/102.png
# /kaggle/input/emojiimage-dataset/image/Windows/1132.png
# /kaggle/input/emojiimage-dataset/image/Windows/254.png
# /kaggle/input/emojiimage-dataset/image/Windows/673.png
# /kaggle/input/emojiimage-dataset/image/Windows/1338.png
# /kaggle/input/emojiimage-dataset/image/Windows/1230.png
# /kaggle/input/emojiimage-dataset/image/Windows/1055.png
# /kaggle/input/emojiimage-dataset/image/Windows/931.png
# /kaggle/input/emojiimage-dataset/image/Windows/245.png
# /kaggle/input/emojiimage-dataset/image/Windows/658.png
# /kaggle/input/emojiimage-dataset/image/Windows/431.png
# /kaggle/input/emojiimage-dataset/image/Windows/465.png
# /kaggle/input/emojiimage-dataset/image/Windows/647.png
# /kaggle/input/emojiimage-dataset/image/Windows/1435.png
# /kaggle/input/emojiimage-dataset/image/Windows/823.png
# /kaggle/input/emojiimage-dataset/image/Windows/1302.png
# /kaggle/input/emojiimage-dataset/image/Windows/891.png
# /kaggle/input/emojiimage-dataset/image/Windows/466.png
# /kaggle/input/emojiimage-dataset/image/Windows/1552.png
# /kaggle/input/emojiimage-dataset/image/Windows/1039.png
# /kaggle/input/emojiimage-dataset/image/Windows/1538.png
# /kaggle/input/emojiimage-dataset/image/Windows/978.png
# /kaggle/input/emojiimage-dataset/image/Windows/689.png
# /kaggle/input/emojiimage-dataset/image/Windows/168.png
# /kaggle/input/emojiimage-dataset/image/Windows/984.png
# /kaggle/input/emojiimage-dataset/image/Windows/857.png
# /kaggle/input/emojiimage-dataset/image/Windows/233.png
# /kaggle/input/emojiimage-dataset/image/Windows/743.png
# /kaggle/input/emojiimage-dataset/image/Windows/1027.png
# /kaggle/input/emojiimage-dataset/image/Windows/713.png
# /kaggle/input/emojiimage-dataset/image/Windows/888.png
# /kaggle/input/emojiimage-dataset/image/Windows/970.png
# /kaggle/input/emojiimage-dataset/image/Windows/818.png
# /kaggle/input/emojiimage-dataset/image/Windows/1490.png
# /kaggle/input/emojiimage-dataset/image/Windows/1495.png
# /kaggle/input/emojiimage-dataset/image/Windows/546.png
# /kaggle/input/emojiimage-dataset/image/Windows/1447.png
# /kaggle/input/emojiimage-dataset/image/Windows/1025.png
# /kaggle/input/emojiimage-dataset/image/Windows/1423.png
# /kaggle/input/emojiimage-dataset/image/Windows/56.png
# /kaggle/input/emojiimage-dataset/image/Windows/911.png
# /kaggle/input/emojiimage-dataset/image/Windows/989.png
# /kaggle/input/emojiimage-dataset/image/Windows/1295.png
# /kaggle/input/emojiimage-dataset/image/Windows/515.png
# /kaggle/input/emojiimage-dataset/image/Windows/1402.png
# /kaggle/input/emojiimage-dataset/image/Windows/1107.png
# /kaggle/input/emojiimage-dataset/image/Windows/578.png
# /kaggle/input/emojiimage-dataset/image/Windows/1228.png
# /kaggle/input/emojiimage-dataset/image/Windows/116.png
# /kaggle/input/emojiimage-dataset/image/Windows/547.png
# /kaggle/input/emojiimage-dataset/image/Windows/1367.png
# /kaggle/input/emojiimage-dataset/image/Windows/555.png
# /kaggle/input/emojiimage-dataset/image/Windows/847.png
# /kaggle/input/emojiimage-dataset/image/Windows/879.png
# /kaggle/input/emojiimage-dataset/image/Windows/1104.png
# /kaggle/input/emojiimage-dataset/image/Windows/533.png
# /kaggle/input/emojiimage-dataset/image/Windows/853.png
# /kaggle/input/emojiimage-dataset/image/Windows/971.png
# /kaggle/input/emojiimage-dataset/image/Windows/520.png
# /kaggle/input/emojiimage-dataset/image/Windows/1047.png
# /kaggle/input/emojiimage-dataset/image/Windows/1288.png
# /kaggle/input/emojiimage-dataset/image/Windows/488.png
# /kaggle/input/emojiimage-dataset/image/Windows/80.png
# /kaggle/input/emojiimage-dataset/image/Windows/698.png
# /kaggle/input/emojiimage-dataset/image/Windows/1150.png
# /kaggle/input/emojiimage-dataset/image/Windows/55.png
# /kaggle/input/emojiimage-dataset/image/Windows/378.png
# /kaggle/input/emojiimage-dataset/image/Windows/965.png
# /kaggle/input/emojiimage-dataset/image/Windows/1541.png
# /kaggle/input/emojiimage-dataset/image/Windows/280.png
# /kaggle/input/emojiimage-dataset/image/Windows/130.png
# /kaggle/input/emojiimage-dataset/image/Windows/592.png
# /kaggle/input/emojiimage-dataset/image/Windows/586.png
# /kaggle/input/emojiimage-dataset/image/Windows/1054.png
# /kaggle/input/emojiimage-dataset/image/Windows/1121.png
# /kaggle/input/emojiimage-dataset/image/Windows/522.png
# /kaggle/input/emojiimage-dataset/image/Windows/291.png
# /kaggle/input/emojiimage-dataset/image/Windows/443.png
# /kaggle/input/emojiimage-dataset/image/Windows/846.png
# /kaggle/input/emojiimage-dataset/image/Windows/50.png
# /kaggle/input/emojiimage-dataset/image/Windows/288.png
# /kaggle/input/emojiimage-dataset/image/Windows/307.png
# /kaggle/input/emojiimage-dataset/image/Windows/840.png
# /kaggle/input/emojiimage-dataset/image/Windows/1335.png
# /kaggle/input/emojiimage-dataset/image/Windows/218.png
# /kaggle/input/emojiimage-dataset/image/Windows/1038.png
# /kaggle/input/emojiimage-dataset/image/Windows/589.png
# /kaggle/input/emojiimage-dataset/image/Windows/607.png
# /kaggle/input/emojiimage-dataset/image/Windows/1078.png
# /kaggle/input/emojiimage-dataset/image/Windows/405.png
# /kaggle/input/emojiimage-dataset/image/Windows/1289.png
# /kaggle/input/emojiimage-dataset/image/Windows/1533.png
# /kaggle/input/emojiimage-dataset/image/Windows/779.png
# /kaggle/input/emojiimage-dataset/image/Windows/1126.png
# /kaggle/input/emojiimage-dataset/image/Windows/1461.png
# /kaggle/input/emojiimage-dataset/image/Windows/199.png
# /kaggle/input/emojiimage-dataset/image/Windows/849.png
# /kaggle/input/emojiimage-dataset/image/Windows/112.png
# /kaggle/input/emojiimage-dataset/image/Windows/755.png
# /kaggle/input/emojiimage-dataset/image/Windows/763.png
# /kaggle/input/emojiimage-dataset/image/Windows/1344.png
# /kaggle/input/emojiimage-dataset/image/Windows/788.png
# /kaggle/input/emojiimage-dataset/image/Windows/501.png
# /kaggle/input/emojiimage-dataset/image/Windows/1394.png
# /kaggle/input/emojiimage-dataset/image/Windows/723.png
# /kaggle/input/emojiimage-dataset/image/Windows/1090.png
# /kaggle/input/emojiimage-dataset/image/Windows/1512.png
# /kaggle/input/emojiimage-dataset/image/Windows/938.png
# /kaggle/input/emojiimage-dataset/image/Windows/49.png
# /kaggle/input/emojiimage-dataset/image/Windows/866.png
# /kaggle/input/emojiimage-dataset/image/Windows/868.png
# /kaggle/input/emojiimage-dataset/image/Windows/1545.png
# /kaggle/input/emojiimage-dataset/image/Windows/327.png
# /kaggle/input/emojiimage-dataset/image/Windows/599.png
# /kaggle/input/emojiimage-dataset/image/Windows/972.png
# /kaggle/input/emojiimage-dataset/image/Windows/747.png
# /kaggle/input/emojiimage-dataset/image/Windows/552.png
# /kaggle/input/emojiimage-dataset/image/Windows/1403.png
# /kaggle/input/emojiimage-dataset/image/Windows/1458.png
# /kaggle/input/emojiimage-dataset/image/Windows/1498.png
# /kaggle/input/emojiimage-dataset/image/Windows/1503.png
# /kaggle/input/emojiimage-dataset/image/Windows/268.png
# /kaggle/input/emojiimage-dataset/image/Windows/1398.png
# /kaggle/input/emojiimage-dataset/image/Windows/775.png
# /kaggle/input/emojiimage-dataset/image/Windows/93.png
# /kaggle/input/emojiimage-dataset/image/Windows/1189.png
# /kaggle/input/emojiimage-dataset/image/Windows/395.png
# /kaggle/input/emojiimage-dataset/image/Windows/1076.png
# /kaggle/input/emojiimage-dataset/image/Windows/150.png
# /kaggle/input/emojiimage-dataset/image/Windows/1003.png
# /kaggle/input/emojiimage-dataset/image/Windows/1238.png
# /kaggle/input/emojiimage-dataset/image/Windows/705.png
# /kaggle/input/emojiimage-dataset/image/Windows/774.png
# /kaggle/input/emojiimage-dataset/image/Windows/1515.png
# /kaggle/input/emojiimage-dataset/image/Windows/113.png
# /kaggle/input/emojiimage-dataset/image/Windows/819.png
# /kaggle/input/emojiimage-dataset/image/Windows/741.png
# /kaggle/input/emojiimage-dataset/image/Windows/332.png
# /kaggle/input/emojiimage-dataset/image/Windows/59.png
# /kaggle/input/emojiimage-dataset/image/Windows/674.png
# /kaggle/input/emojiimage-dataset/image/Windows/880.png
# /kaggle/input/emojiimage-dataset/image/Windows/1163.png
# /kaggle/input/emojiimage-dataset/image/Windows/1519.png
# /kaggle/input/emojiimage-dataset/image/Windows/316.png
# /kaggle/input/emojiimage-dataset/image/Windows/785.png
# /kaggle/input/emojiimage-dataset/image/Windows/434.png
# /kaggle/input/emojiimage-dataset/image/Windows/949.png
# /kaggle/input/emojiimage-dataset/image/Windows/169.png
# /kaggle/input/emojiimage-dataset/image/Windows/529.png
# /kaggle/input/emojiimage-dataset/image/Windows/301.png
# /kaggle/input/emojiimage-dataset/image/Windows/289.png
# /kaggle/input/emojiimage-dataset/image/Windows/1379.png
# /kaggle/input/emojiimage-dataset/image/Windows/170.png
# /kaggle/input/emojiimage-dataset/image/Windows/860.png
# /kaggle/input/emojiimage-dataset/image/Windows/194.png
# /kaggle/input/emojiimage-dataset/image/Windows/136.png
# /kaggle/input/emojiimage-dataset/image/Windows/1139.png
# /kaggle/input/emojiimage-dataset/image/Windows/976.png
# /kaggle/input/emojiimage-dataset/image/Windows/198.png
# /kaggle/input/emojiimage-dataset/image/Windows/724.png
# /kaggle/input/emojiimage-dataset/image/Windows/683.png
# /kaggle/input/emojiimage-dataset/image/Windows/1178.png
# /kaggle/input/emojiimage-dataset/image/Windows/640.png
# /kaggle/input/emojiimage-dataset/image/Windows/924.png
# /kaggle/input/emojiimage-dataset/image/Windows/1246.png
# /kaggle/input/emojiimage-dataset/image/Windows/401.png
# /kaggle/input/emojiimage-dataset/image/Windows/1553.png
# /kaggle/input/emojiimage-dataset/image/Windows/816.png
# /kaggle/input/emojiimage-dataset/image/Windows/14.png
# /kaggle/input/emojiimage-dataset/image/Windows/1029.png
# /kaggle/input/emojiimage-dataset/image/Windows/65.png
# /kaggle/input/emojiimage-dataset/image/Windows/161.png
# /kaggle/input/emojiimage-dataset/image/Windows/1093.png
# /kaggle/input/emojiimage-dataset/image/Windows/892.png
# /kaggle/input/emojiimage-dataset/image/Windows/371.png
# /kaggle/input/emojiimage-dataset/image/Windows/784.png
# /kaggle/input/emojiimage-dataset/image/Windows/1.png
# /kaggle/input/emojiimage-dataset/image/Windows/1073.png
# /kaggle/input/emojiimage-dataset/image/Windows/706.png
# /kaggle/input/emojiimage-dataset/image/Windows/576.png
# /kaggle/input/emojiimage-dataset/image/Windows/1325.png
# /kaggle/input/emojiimage-dataset/image/Windows/1157.png
# /kaggle/input/emojiimage-dataset/image/Windows/798.png
# /kaggle/input/emojiimage-dataset/image/Windows/1437.png
# /kaggle/input/emojiimage-dataset/image/Windows/574.png
# /kaggle/input/emojiimage-dataset/image/Windows/701.png
# /kaggle/input/emojiimage-dataset/image/Windows/367.png
# /kaggle/input/emojiimage-dataset/image/Windows/484.png
# /kaggle/input/emojiimage-dataset/image/Windows/1019.png
# /kaggle/input/emojiimage-dataset/image/Windows/325.png
# /kaggle/input/emojiimage-dataset/image/Windows/1390.png
# /kaggle/input/emojiimage-dataset/image/Windows/1276.png
# /kaggle/input/emojiimage-dataset/image/Windows/1499.png
# /kaggle/input/emojiimage-dataset/image/Windows/1372.png
# /kaggle/input/emojiimage-dataset/image/Windows/108.png
# /kaggle/input/emojiimage-dataset/image/Windows/1291.png
# /kaggle/input/emojiimage-dataset/image/Windows/1509.png
# /kaggle/input/emojiimage-dataset/image/Windows/926.png
# /kaggle/input/emojiimage-dataset/image/Windows/1109.png
# /kaggle/input/emojiimage-dataset/image/Windows/39.png
# /kaggle/input/emojiimage-dataset/image/Windows/360.png
# /kaggle/input/emojiimage-dataset/image/Windows/748.png
# /kaggle/input/emojiimage-dataset/image/Windows/1250.png
# /kaggle/input/emojiimage-dataset/image/Windows/1144.png
# /kaggle/input/emojiimage-dataset/image/Windows/458.png
# /kaggle/input/emojiimage-dataset/image/Windows/380.png
# /kaggle/input/emojiimage-dataset/image/Windows/1143.png
# /kaggle/input/emojiimage-dataset/image/Windows/610.png
# /kaggle/input/emojiimage-dataset/image/Windows/446.png
# /kaggle/input/emojiimage-dataset/image/Windows/132.png
# /kaggle/input/emojiimage-dataset/image/Windows/424.png
# /kaggle/input/emojiimage-dataset/image/Windows/1404.png
# /kaggle/input/emojiimage-dataset/image/Windows/1520.png
# /kaggle/input/emojiimage-dataset/image/Windows/781.png
# /kaggle/input/emojiimage-dataset/image/Windows/912.png
# /kaggle/input/emojiimage-dataset/image/Windows/1407.png
# /kaggle/input/emojiimage-dataset/image/Windows/715.png
# /kaggle/input/emojiimage-dataset/image/Windows/1488.png
# /kaggle/input/emojiimage-dataset/image/Windows/549.png
# /kaggle/input/emojiimage-dataset/image/Windows/1409.png
# /kaggle/input/emojiimage-dataset/image/Windows/433.png
# /kaggle/input/emojiimage-dataset/image/Windows/156.png
# /kaggle/input/emojiimage-dataset/image/Windows/856.png
# /kaggle/input/emojiimage-dataset/image/Windows/1105.png
# /kaggle/input/emojiimage-dataset/image/Windows/1555.png
# /kaggle/input/emojiimage-dataset/image/Windows/370.png
# /kaggle/input/emojiimage-dataset/image/Windows/767.png
# /kaggle/input/emojiimage-dataset/image/Windows/777.png
# /kaggle/input/emojiimage-dataset/image/Windows/319.png
# /kaggle/input/emojiimage-dataset/image/Windows/696.png
# /kaggle/input/emojiimage-dataset/image/Windows/609.png
# /kaggle/input/emojiimage-dataset/image/Windows/107.png
# /kaggle/input/emojiimage-dataset/image/Windows/790.png
# /kaggle/input/emojiimage-dataset/image/Windows/1436.png
# /kaggle/input/emojiimage-dataset/image/Windows/372.png
# /kaggle/input/emojiimage-dataset/image/Windows/1216.png
# /kaggle/input/emojiimage-dataset/image/Windows/1471.png
# /kaggle/input/emojiimage-dataset/image/Windows/90.png
# /kaggle/input/emojiimage-dataset/image/Windows/1540.png
# /kaggle/input/emojiimage-dataset/image/Windows/262.png
# /kaggle/input/emojiimage-dataset/image/Windows/364.png
# /kaggle/input/emojiimage-dataset/image/Windows/1311.png
# /kaggle/input/emojiimage-dataset/image/Windows/215.png
# /kaggle/input/emojiimage-dataset/image/Windows/1235.png
# /kaggle/input/emojiimage-dataset/image/Windows/958.png
# /kaggle/input/emojiimage-dataset/image/Windows/1446.png
# /kaggle/input/emojiimage-dataset/image/Windows/1504.png
# /kaggle/input/emojiimage-dataset/image/Windows/414.png
# /kaggle/input/emojiimage-dataset/image/Windows/920.png
# /kaggle/input/emojiimage-dataset/image/Windows/614.png
# /kaggle/input/emojiimage-dataset/image/Windows/439.png
# /kaggle/input/emojiimage-dataset/image/Windows/1111.png
# /kaggle/input/emojiimage-dataset/image/Windows/20.png
# /kaggle/input/emojiimage-dataset/image/Windows/1459.png
# /kaggle/input/emojiimage-dataset/image/Windows/181.png
# /kaggle/input/emojiimage-dataset/image/Windows/471.png
# /kaggle/input/emojiimage-dataset/image/Windows/83.png
# /kaggle/input/emojiimage-dataset/image/Windows/829.png
# /kaggle/input/emojiimage-dataset/image/Windows/412.png
# /kaggle/input/emojiimage-dataset/image/Windows/597.png
# /kaggle/input/emojiimage-dataset/image/Windows/1102.png
# /kaggle/input/emojiimage-dataset/image/Windows/809.png
# /kaggle/input/emojiimage-dataset/image/Windows/467.png
# /kaggle/input/emojiimage-dataset/image/Windows/910.png
# /kaggle/input/emojiimage-dataset/image/Windows/473.png
# /kaggle/input/emojiimage-dataset/image/Windows/1442.png
# /kaggle/input/emojiimage-dataset/image/Windows/1083.png
# /kaggle/input/emojiimage-dataset/image/Windows/426.png
# /kaggle/input/emojiimage-dataset/image/Windows/770.png
# /kaggle/input/emojiimage-dataset/image/Windows/731.png
# /kaggle/input/emojiimage-dataset/image/Windows/1136.png
# /kaggle/input/emojiimage-dataset/image/Windows/691.png
# /kaggle/input/emojiimage-dataset/image/Windows/1190.png
# /kaggle/input/emojiimage-dataset/image/Windows/864.png
# /kaggle/input/emojiimage-dataset/image/Windows/1271.png
# /kaggle/input/emojiimage-dataset/image/Windows/1284.png
# /kaggle/input/emojiimage-dataset/image/Windows/1313.png
# /kaggle/input/emojiimage-dataset/image/Windows/38.png
# /kaggle/input/emojiimage-dataset/image/Windows/1182.png
# /kaggle/input/emojiimage-dataset/image/Windows/1247.png
# /kaggle/input/emojiimage-dataset/image/Windows/1009.png
# /kaggle/input/emojiimage-dataset/image/Windows/151.png
# /kaggle/input/emojiimage-dataset/image/Windows/913.png
# /kaggle/input/emojiimage-dataset/image/Windows/1209.png
# /kaggle/input/emojiimage-dataset/image/Windows/2.png
# /kaggle/input/emojiimage-dataset/image/Windows/900.png
# /kaggle/input/emojiimage-dataset/image/Windows/806.png
# /kaggle/input/emojiimage-dataset/image/Windows/1005.png
# /kaggle/input/emojiimage-dataset/image/Windows/1385.png
# /kaggle/input/emojiimage-dataset/image/Windows/530.png
# /kaggle/input/emojiimage-dataset/image/Windows/1033.png
# /kaggle/input/emojiimage-dataset/image/Windows/1467.png
# /kaggle/input/emojiimage-dataset/image/Windows/1089.png
# /kaggle/input/emojiimage-dataset/image/Windows/349.png
# /kaggle/input/emojiimage-dataset/image/Windows/702.png
# /kaggle/input/emojiimage-dataset/image/Windows/886.png
# /kaggle/input/emojiimage-dataset/image/Windows/223.png
# /kaggle/input/emojiimage-dataset/image/Windows/1115.png
# /kaggle/input/emojiimage-dataset/image/Windows/1253.png
# /kaggle/input/emojiimage-dataset/image/Windows/10.png
# /kaggle/input/emojiimage-dataset/image/Windows/1070.png
# /kaggle/input/emojiimage-dataset/image/Windows/598.png
# /kaggle/input/emojiimage-dataset/image/Windows/956.png
# /kaggle/input/emojiimage-dataset/image/Windows/1180.png
# /kaggle/input/emojiimage-dataset/image/Windows/1223.png
# /kaggle/input/emojiimage-dataset/image/Windows/82.png
# /kaggle/input/emojiimage-dataset/image/Windows/1215.png
# /kaggle/input/emojiimage-dataset/image/Windows/1119.png
# /kaggle/input/emojiimage-dataset/image/Windows/1346.png
# /kaggle/input/emojiimage-dataset/image/Windows/1120.png
# /kaggle/input/emojiimage-dataset/image/Windows/460.png
# /kaggle/input/emojiimage-dataset/image/Windows/242.png
# /kaggle/input/emojiimage-dataset/image/Windows/404.png
# /kaggle/input/emojiimage-dataset/image/Windows/251.png
# /kaggle/input/emojiimage-dataset/image/Windows/174.png
# /kaggle/input/emojiimage-dataset/image/Windows/808.png
# /kaggle/input/emojiimage-dataset/image/Windows/1480.png
# /kaggle/input/emojiimage-dataset/image/Windows/250.png
# /kaggle/input/emojiimage-dataset/image/Windows/943.png
# /kaggle/input/emojiimage-dataset/image/Windows/440.png
# /kaggle/input/emojiimage-dataset/image/Windows/1169.png
# /kaggle/input/emojiimage-dataset/image/Windows/1008.png
# /kaggle/input/emojiimage-dataset/image/Windows/131.png
# /kaggle/input/emojiimage-dataset/image/Windows/1162.png
# /kaggle/input/emojiimage-dataset/image/Windows/36.png
# /kaggle/input/emojiimage-dataset/image/Windows/953.png
# /kaggle/input/emojiimage-dataset/image/Windows/1129.png
# /kaggle/input/emojiimage-dataset/image/Windows/1193.png
# /kaggle/input/emojiimage-dataset/image/Windows/157.png
# /kaggle/input/emojiimage-dataset/image/Windows/182.png
# /kaggle/input/emojiimage-dataset/image/Windows/143.png
# /kaggle/input/emojiimage-dataset/image/Windows/852.png
# /kaggle/input/emojiimage-dataset/image/Windows/1360.png
# /kaggle/input/emojiimage-dataset/image/Windows/221.png
# /kaggle/input/emojiimage-dataset/image/Windows/968.png
# /kaggle/input/emojiimage-dataset/image/Windows/746.png
# /kaggle/input/emojiimage-dataset/image/Windows/383.png
# /kaggle/input/emojiimage-dataset/image/Windows/570.png
# /kaggle/input/emojiimage-dataset/image/Windows/1225.png
# /kaggle/input/emojiimage-dataset/image/Windows/835.png
# /kaggle/input/emojiimage-dataset/image/Windows/700.png
# /kaggle/input/emojiimage-dataset/image/Windows/208.png
# /kaggle/input/emojiimage-dataset/image/Windows/1014.png
# /kaggle/input/emojiimage-dataset/image/Windows/1201.png
# /kaggle/input/emojiimage-dataset/image/Windows/152.png
# /kaggle/input/emojiimage-dataset/image/Windows/1492.png
# /kaggle/input/emojiimage-dataset/image/Windows/137.png
# /kaggle/input/emojiimage-dataset/image/Windows/1448.png
# /kaggle/input/emojiimage-dataset/image/Windows/906.png
# /kaggle/input/emojiimage-dataset/image/Windows/908.png
# /kaggle/input/emojiimage-dataset/image/Windows/1063.png
# /kaggle/input/emojiimage-dataset/image/Windows/556.png
# /kaggle/input/emojiimage-dataset/image/Windows/312.png
# /kaggle/input/emojiimage-dataset/image/Windows/1287.png
# /kaggle/input/emojiimage-dataset/image/Windows/81.png
# /kaggle/input/emojiimage-dataset/image/Windows/1152.png
# /kaggle/input/emojiimage-dataset/image/Windows/239.png
# /kaggle/input/emojiimage-dataset/image/Windows/1391.png
# /kaggle/input/emojiimage-dataset/image/Windows/1125.png
# /kaggle/input/emojiimage-dataset/image/Windows/1239.png
# /kaggle/input/emojiimage-dataset/image/Windows/1155.png
# /kaggle/input/emojiimage-dataset/image/Windows/66.png
# /kaggle/input/emojiimage-dataset/image/Windows/58.png
# /kaggle/input/emojiimage-dataset/image/Windows/1292.png
# /kaggle/input/emojiimage-dataset/image/Windows/1293.png
# /kaggle/input/emojiimage-dataset/image/Windows/661.png
# /kaggle/input/emojiimage-dataset/image/Windows/453.png
# /kaggle/input/emojiimage-dataset/image/Windows/417.png
# /kaggle/input/emojiimage-dataset/image/Windows/483.png
# /kaggle/input/emojiimage-dataset/image/Windows/1091.png
# /kaggle/input/emojiimage-dataset/image/Windows/764.png
# /kaggle/input/emojiimage-dataset/image/Windows/897.png
# /kaggle/input/emojiimage-dataset/image/Windows/960.png
# /kaggle/input/emojiimage-dataset/image/Windows/902.png
# /kaggle/input/emojiimage-dataset/image/Windows/732.png
# /kaggle/input/emojiimage-dataset/image/Windows/1213.png
# /kaggle/input/emojiimage-dataset/image/Windows/214.png
# /kaggle/input/emojiimage-dataset/image/Windows/979.png
# /kaggle/input/emojiimage-dataset/image/Windows/1183.png
# /kaggle/input/emojiimage-dataset/image/Windows/1353.png
# /kaggle/input/emojiimage-dataset/image/Windows/1085.png
# /kaggle/input/emojiimage-dataset/image/Windows/122.png
# /kaggle/input/emojiimage-dataset/image/Windows/639.png
# /kaggle/input/emojiimage-dataset/image/Windows/684.png
# /kaggle/input/emojiimage-dataset/image/Windows/712.png
# /kaggle/input/emojiimage-dataset/image/Windows/932.png
# /kaggle/input/emojiimage-dataset/image/Windows/735.png
# /kaggle/input/emojiimage-dataset/image/Windows/734.png
# /kaggle/input/emojiimage-dataset/image/Windows/722.png
# /kaggle/input/emojiimage-dataset/image/Windows/914.png
# /kaggle/input/emojiimage-dataset/image/Windows/855.png
# /kaggle/input/emojiimage-dataset/image/Windows/1476.png
# /kaggle/input/emojiimage-dataset/image/Windows/934.png
# /kaggle/input/emojiimage-dataset/image/Windows/276.png
# /kaggle/input/emojiimage-dataset/image/Windows/1470.png
# /kaggle/input/emojiimage-dataset/image/Windows/848.png
# /kaggle/input/emojiimage-dataset/image/Windows/1270.png
# /kaggle/input/emojiimage-dataset/image/Windows/865.png
# /kaggle/input/emojiimage-dataset/image/Windows/1388.png
# /kaggle/input/emojiimage-dataset/image/Windows/939.png
# /kaggle/input/emojiimage-dataset/image/Windows/1366.png
# /kaggle/input/emojiimage-dataset/image/Windows/1277.png
# /kaggle/input/emojiimage-dataset/image/Windows/187.png
# /kaggle/input/emojiimage-dataset/image/Windows/1248.png
# /kaggle/input/emojiimage-dataset/image/Windows/996.png
# /kaggle/input/emojiimage-dataset/image/Windows/1439.png
# /kaggle/input/emojiimage-dataset/image/Windows/1204.png
# /kaggle/input/emojiimage-dataset/image/Windows/106.png
# /kaggle/input/emojiimage-dataset/image/Windows/585.png
# /kaggle/input/emojiimage-dataset/image/Windows/279.png
# /kaggle/input/emojiimage-dataset/image/Windows/1114.png
# /kaggle/input/emojiimage-dataset/image/Windows/577.png
# /kaggle/input/emojiimage-dataset/image/Windows/1382.png
# /kaggle/input/emojiimage-dataset/image/Windows/356.png
# /kaggle/input/emojiimage-dataset/image/Windows/117.png
# /kaggle/input/emojiimage-dataset/image/Windows/937.png
# /kaggle/input/emojiimage-dataset/image/Windows/1419.png
# /kaggle/input/emojiimage-dataset/image/Windows/917.png
# /kaggle/input/emojiimage-dataset/image/Windows/220.png
# /kaggle/input/emojiimage-dataset/image/Windows/277.png
# /kaggle/input/emojiimage-dataset/image/Windows/617.png
# /kaggle/input/emojiimage-dataset/image/Windows/584.png
# /kaggle/input/emojiimage-dataset/image/Windows/1196.png
# /kaggle/input/emojiimage-dataset/image/Windows/300.png
# /kaggle/input/emojiimage-dataset/image/Windows/425.png
# /kaggle/input/emojiimage-dataset/image/Windows/1484.png
# /kaggle/input/emojiimage-dataset/image/Windows/244.png
# /kaggle/input/emojiimage-dataset/image/Windows/329.png
# /kaggle/input/emojiimage-dataset/image/Windows/282.png
# /kaggle/input/emojiimage-dataset/image/Windows/890.png
# /kaggle/input/emojiimage-dataset/image/Windows/1465.png
# /kaggle/input/emojiimage-dataset/image/Windows/1440.png
# /kaggle/input/emojiimage-dataset/image/Windows/1192.png
# /kaggle/input/emojiimage-dataset/image/Windows/1138.png
# /kaggle/input/emojiimage-dataset/image/Windows/263.png
# /kaggle/input/emojiimage-dataset/image/Windows/1317.png
# /kaggle/input/emojiimage-dataset/image/Windows/354.png
# /kaggle/input/emojiimage-dataset/image/Windows/650.png
# /kaggle/input/emojiimage-dataset/image/Windows/1022.png
# /kaggle/input/emojiimage-dataset/image/Windows/166.png
# /kaggle/input/emojiimage-dataset/image/Windows/1345.png
# /kaggle/input/emojiimage-dataset/image/Windows/594.png
# /kaggle/input/emojiimage-dataset/image/Windows/582.png
# /kaggle/input/emojiimage-dataset/image/Windows/1355.png
# /kaggle/input/emojiimage-dataset/image/Windows/947.png
# /kaggle/input/emojiimage-dataset/image/Windows/1260.png
# /kaggle/input/emojiimage-dataset/image/Windows/680.png
# /kaggle/input/emojiimage-dataset/image/Windows/1527.png
# /kaggle/input/emojiimage-dataset/image/Windows/1523.png
# /kaggle/input/emojiimage-dataset/image/Windows/1181.png
# /kaggle/input/emojiimage-dataset/image/Windows/320.png
# /kaggle/input/emojiimage-dataset/image/Windows/1020.png
# /kaggle/input/emojiimage-dataset/image/Windows/1468.png
# /kaggle/input/emojiimage-dataset/image/Windows/1518.png
# /kaggle/input/emojiimage-dataset/image/Windows/952.png
# /kaggle/input/emojiimage-dataset/image/Windows/437.png
# /kaggle/input/emojiimage-dataset/image/Windows/572.png
# /kaggle/input/emojiimage-dataset/image/Windows/997.png
# /kaggle/input/emojiimage-dataset/image/Windows/18.png
# /kaggle/input/emojiimage-dataset/image/Windows/63.png
# /kaggle/input/emojiimage-dataset/image/Windows/455.png
# /kaggle/input/emojiimage-dataset/image/Windows/1259.png
# /kaggle/input/emojiimage-dataset/image/Windows/1473.png
# /kaggle/input/emojiimage-dataset/image/Windows/1164.png
# /kaggle/input/emojiimage-dataset/image/Windows/1286.png
# /kaggle/input/emojiimage-dataset/image/Windows/936.png
# /kaggle/input/emojiimage-dataset/image/Windows/1079.png
# /kaggle/input/emojiimage-dataset/image/Windows/1449.png
# /kaggle/input/emojiimage-dataset/image/Windows/435.png
# /kaggle/input/emojiimage-dataset/image/Windows/294.png
# /kaggle/input/emojiimage-dataset/image/Windows/745.png
# /kaggle/input/emojiimage-dataset/image/Windows/264.png
# /kaggle/input/emojiimage-dataset/image/Windows/21.png
# /kaggle/input/emojiimage-dataset/image/Windows/1546.png
# /kaggle/input/emojiimage-dataset/image/Windows/954.png
# /kaggle/input/emojiimage-dataset/image/Windows/495.png
# /kaggle/input/emojiimage-dataset/image/Windows/12.png
# /kaggle/input/emojiimage-dataset/image/Windows/739.png
# /kaggle/input/emojiimage-dataset/image/Windows/514.png
# /kaggle/input/emojiimage-dataset/image/Windows/720.png
# /kaggle/input/emojiimage-dataset/image/Windows/792.png
# /kaggle/input/emojiimage-dataset/image/Windows/98.png
# /kaggle/input/emojiimage-dataset/image/Windows/1454.png
# /kaggle/input/emojiimage-dataset/image/Windows/127.png
# /kaggle/input/emojiimage-dataset/image/Windows/666.png
# /kaggle/input/emojiimage-dataset/image/Windows/1166.png
# /kaggle/input/emojiimage-dataset/image/Windows/1358.png
# /kaggle/input/emojiimage-dataset/image/Windows/415.png
# /kaggle/input/emojiimage-dataset/image/Windows/553.png
# /kaggle/input/emojiimage-dataset/image/Windows/219.png
# /kaggle/input/emojiimage-dataset/image/Windows/184.png
# /kaggle/input/emojiimage-dataset/image/Windows/1056.png
# /kaggle/input/emojiimage-dataset/image/Windows/782.png
# /kaggle/input/emojiimage-dataset/image/Windows/1082.png
# /kaggle/input/emojiimage-dataset/image/Windows/795.png
# /kaggle/input/emojiimage-dataset/image/Windows/627.png
# /kaggle/input/emojiimage-dataset/image/Windows/1534.png
# /kaggle/input/emojiimage-dataset/image/Windows/1478.png
# /kaggle/input/emojiimage-dataset/image/Windows/1195.png
# /kaggle/input/emojiimage-dataset/image/Windows/1341.png
# /kaggle/input/emojiimage-dataset/image/Windows/1384.png
# /kaggle/input/emojiimage-dataset/image/Windows/1460.png
# /kaggle/input/emojiimage-dataset/image/Windows/873.png
# /kaggle/input/emojiimage-dataset/image/Windows/810.png
# /kaggle/input/emojiimage-dataset/image/Windows/1550.png
# /kaggle/input/emojiimage-dataset/image/Windows/751.png
# /kaggle/input/emojiimage-dataset/image/Windows/510.png
# /kaggle/input/emojiimage-dataset/image/Windows/28.png
# /kaggle/input/emojiimage-dataset/image/Windows/1171.png
# /kaggle/input/emojiimage-dataset/image/Windows/1167.png
# /kaggle/input/emojiimage-dataset/image/Windows/190.png
# /kaggle/input/emojiimage-dataset/image/Windows/490.png
# /kaggle/input/emojiimage-dataset/image/Windows/1043.png
# /kaggle/input/emojiimage-dataset/image/Windows/1531.png
# /kaggle/input/emojiimage-dataset/image/Windows/165.png
# /kaggle/input/emojiimage-dataset/image/Windows/1257.png
# /kaggle/input/emojiimage-dataset/image/Windows/1549.png
# /kaggle/input/emojiimage-dataset/image/Windows/402.png
# /kaggle/input/emojiimage-dataset/image/Windows/988.png
# /kaggle/input/emojiimage-dataset/image/Windows/1383.png
# /kaggle/input/emojiimage-dataset/image/Windows/1368.png
# /kaggle/input/emojiimage-dataset/image/Windows/464.png
# /kaggle/input/emojiimage-dataset/image/Windows/202.png
# /kaggle/input/emojiimage-dataset/image/Windows/247.png
# /kaggle/input/emojiimage-dataset/image/Windows/831.png
# /kaggle/input/emojiimage-dataset/image/Windows/1418.png
# /kaggle/input/emojiimage-dataset/image/Windows/1030.png
# /kaggle/input/emojiimage-dataset/image/Windows/368.png
# /kaggle/input/emojiimage-dataset/image/Windows/758.png
# /kaggle/input/emojiimage-dataset/image/Windows/1049.png
# /kaggle/input/emojiimage-dataset/image/Windows/1369.png
# /kaggle/input/emojiimage-dataset/image/Windows/1134.png
# /kaggle/input/emojiimage-dataset/image/Windows/469.png
# /kaggle/input/emojiimage-dataset/image/Windows/1153.png
# /kaggle/input/emojiimage-dataset/image/Windows/602.png
# /kaggle/input/emojiimage-dataset/image/Windows/1188.png
# /kaggle/input/emojiimage-dataset/image/Windows/476.png
# /kaggle/input/emojiimage-dataset/image/Windows/481.png
# /kaggle/input/emojiimage-dataset/image/Windows/1489.png
# /kaggle/input/emojiimage-dataset/image/Windows/944.png
# /kaggle/input/emojiimage-dataset/image/Windows/1217.png
# /kaggle/input/emojiimage-dataset/image/Windows/559.png
# /kaggle/input/emojiimage-dataset/image/Windows/1044.png
# /kaggle/input/emojiimage-dataset/image/Windows/447.png
# /kaggle/input/emojiimage-dataset/image/Windows/742.png
# /kaggle/input/emojiimage-dataset/image/Windows/67.png
# /kaggle/input/emojiimage-dataset/image/Windows/1481.png
# /kaggle/input/emojiimage-dataset/image/Windows/96.png
# /kaggle/input/emojiimage-dataset/image/Windows/1393.png
# /kaggle/input/emojiimage-dataset/image/Windows/243.png
# /kaggle/input/emojiimage-dataset/image/Windows/502.png
# /kaggle/input/emojiimage-dataset/image/Windows/603.png
# /kaggle/input/emojiimage-dataset/image/Windows/1106.png
# /kaggle/input/emojiimage-dataset/image/Windows/34.png
# ...
# /kaggle/input/emojiimage-dataset/image/Gmail/1217.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1044.png
# /kaggle/input/emojiimage-dataset/image/Gmail/742.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1481.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1393.png
# /kaggle/input/emojiimage-dataset/image/Gmail/502.png
# /kaggle/input/emojiimage-dataset/image/Gmail/603.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1506.png
# /kaggle/input/emojiimage-dataset/image/Gmail/896.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1357.png
# /kaggle/input/emojiimage-dataset/image/Gmail/813.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1233.png
# /kaggle/input/emojiimage-dataset/image/Gmail/945.png
# /kaggle/input/emojiimage-dataset/image/Gmail/814.png
# /kaggle/input/emojiimage-dataset/image/Gmail/662.png
# /kaggle/input/emojiimage-dataset/image/Gmail/995.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1232.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1068.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1057.png
# /kaggle/input/emojiimage-dataset/image/Gmail/923.png
# /kaggle/input/emojiimage-dataset/image/Gmail/554.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1635.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1683.png
# /kaggle/input/emojiimage-dataset/image/Gmail/756.png
# /kaggle/input/emojiimage-dataset/image/Gmail/596.png
# /kaggle/input/emojiimage-dataset/image/Gmail/105.png
# /kaggle/input/emojiimage-dataset/image/Gmail/125.png
# /kaggle/input/emojiimage-dataset/image/Gmail/121.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1026.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1455.png
# /kaggle/input/emojiimage-dataset/image/Gmail/216.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1438.png
# /kaggle/input/emojiimage-dataset/image/Gmail/656.png
# /kaggle/input/emojiimage-dataset/image/Gmail/337.png
# /kaggle/input/emojiimage-dataset/image/Gmail/69.png
# /kaggle/input/emojiimage-dataset/image/Gmail/146.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1433.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1543.png
# /kaggle/input/emojiimage-dataset/image/Gmail/991.png
# /kaggle/input/emojiimage-dataset/image/Gmail/637.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1146.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1280.png
# /kaggle/input/emojiimage-dataset/image/Gmail/663.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1444.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1486.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1185.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1537.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1298.png
# /kaggle/input/emojiimage-dataset/image/Gmail/805.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1399.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1173.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1796.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1098.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1421.png
# /kaggle/input/emojiimage-dataset/image/Gmail/86.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1410.png
# /kaggle/input/emojiimage-dataset/image/Gmail/836.png
# /kaggle/input/emojiimage-dataset/image/Gmail/916.png
# /kaggle/input/emojiimage-dataset/image/Gmail/894.png
# /kaggle/input/emojiimage-dataset/image/Gmail/838.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1485.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1051.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1242.png
# /kaggle/input/emojiimage-dataset/image/Gmail/103.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1007.png
# /kaggle/input/emojiimage-dataset/image/Gmail/833.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1200.png
# /kaggle/input/emojiimage-dataset/image/Gmail/144.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1412.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1508.png
# /kaggle/input/emojiimage-dataset/image/Gmail/644.png
# /kaggle/input/emojiimage-dataset/image/Gmail/109.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1510.png
# /kaggle/input/emojiimage-dataset/image/Gmail/697.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1205.png
# /kaggle/input/emojiimage-dataset/image/Gmail/861.png
# /kaggle/input/emojiimage-dataset/image/Gmail/753.png
# /kaggle/input/emojiimage-dataset/image/Gmail/567.png
# /kaggle/input/emojiimage-dataset/image/Gmail/526.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1521.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1511.png
# /kaggle/input/emojiimage-dataset/image/Gmail/648.png
# /kaggle/input/emojiimage-dataset/image/Gmail/573.png
# /kaggle/input/emojiimage-dataset/image/Gmail/74.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1001.png
# /kaggle/input/emojiimage-dataset/image/Gmail/653.png
# /kaggle/input/emojiimage-dataset/image/Gmail/120.png
# /kaggle/input/emojiimage-dataset/image/Gmail/935.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1411.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1502.png
# /kaggle/input/emojiimage-dataset/image/Gmail/118.png
# /kaggle/input/emojiimage-dataset/image/Gmail/670.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1451.png
# /kaggle/input/emojiimage-dataset/image/Gmail/17.png
# /kaggle/input/emojiimage-dataset/image/Gmail/196.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1191.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1536.png
# /kaggle/input/emojiimage-dataset/image/Gmail/179.png
# /kaggle/input/emojiimage-dataset/image/Gmail/178.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1186.png
# /kaggle/input/emojiimage-dataset/image/Gmail/160.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1245.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1387.png
# /kaggle/input/emojiimage-dataset/image/Gmail/636.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1140.png
# /kaggle/input/emojiimage-dataset/image/Gmail/5.png
# /kaggle/input/emojiimage-dataset/image/Gmail/139.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1475.png
# /kaggle/input/emojiimage-dataset/image/Gmail/3.png
# /kaggle/input/emojiimage-dataset/image/Gmail/828.png
# /kaggle/input/emojiimage-dataset/image/Gmail/172.png
# /kaggle/input/emojiimage-dataset/image/Gmail/950.png
# /kaggle/input/emojiimage-dataset/image/Gmail/841.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1011.png
# /kaggle/input/emojiimage-dataset/image/Gmail/406.png
# /kaggle/input/emojiimage-dataset/image/Gmail/719.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1456.png
# /kaggle/input/emojiimage-dataset/image/Gmail/955.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1028.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1496.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1428.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1544.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1244.png
# /kaggle/input/emojiimage-dataset/image/Gmail/967.png
# /kaggle/input/emojiimage-dataset/image/Gmail/925.png
# /kaggle/input/emojiimage-dataset/image/Gmail/725.png
# /kaggle/input/emojiimage-dataset/image/Gmail/328.png
# /kaggle/input/emojiimage-dataset/image/Gmail/643.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1127.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1099.png
# /kaggle/input/emojiimage-dataset/image/Gmail/804.png
# /kaggle/input/emojiimage-dataset/image/Gmail/461.png
# /kaggle/input/emojiimage-dataset/image/Gmail/8.png
# /kaggle/input/emojiimage-dataset/image/Gmail/45.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1466.png
# /kaggle/input/emojiimage-dataset/image/Gmail/382.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1434.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1432.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1066.png
# /kaggle/input/emojiimage-dataset/image/Gmail/941.png
# /kaggle/input/emojiimage-dataset/image/Gmail/88.png
# /kaggle/input/emojiimage-dataset/image/Gmail/986.png
# /kaggle/input/emojiimage-dataset/image/Gmail/649.png
# /kaggle/input/emojiimage-dataset/image/Gmail/115.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1362.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1422.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1273.png
# /kaggle/input/emojiimage-dataset/image/Gmail/749.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1040.png
# /kaggle/input/emojiimage-dataset/image/Gmail/128.png
# /kaggle/input/emojiimage-dataset/image/Gmail/710.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1386.png
# /kaggle/input/emojiimage-dataset/image/Gmail/807.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1359.png
# /kaggle/input/emojiimage-dataset/image/Gmail/6.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1226.png
# /kaggle/input/emojiimage-dataset/image/Gmail/23.png
# /kaggle/input/emojiimage-dataset/image/Gmail/87.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1100.png
# /kaggle/input/emojiimage-dataset/image/Gmail/987.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1218.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1234.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1194.png
# /kaggle/input/emojiimage-dataset/image/Gmail/728.png
# /kaggle/input/emojiimage-dataset/image/Gmail/400.png
# /kaggle/input/emojiimage-dataset/image/Gmail/606.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1202.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1158.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1501.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1133.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1305.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1002.png
# /kaggle/input/emojiimage-dataset/image/Gmail/740.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1069.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1472.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1016.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1429.png
# /kaggle/input/emojiimage-dataset/image/Gmail/123.png
# /kaggle/input/emojiimage-dataset/image/Gmail/862.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1464.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1151.png
# /kaggle/input/emojiimage-dataset/image/Gmail/189.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1112.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1539.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1462.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1021.png
# /kaggle/input/emojiimage-dataset/image/Gmail/541.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1174.png
# /kaggle/input/emojiimage-dataset/image/Gmail/601.png
# /kaggle/input/emojiimage-dataset/image/Gmail/839.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1374.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1065.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1535.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1052.png
# /kaggle/input/emojiimage-dataset/image/Gmail/68.png
# /kaggle/input/emojiimage-dataset/image/Gmail/422.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1256.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1474.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1505.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1370.png
# /kaggle/input/emojiimage-dataset/image/Gmail/46.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1237.png
# /kaggle/input/emojiimage-dataset/image/Gmail/929.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1389.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1236.png
# /kaggle/input/emojiimage-dataset/image/Gmail/84.png
# /kaggle/input/emojiimage-dataset/image/Gmail/475.png
# /kaggle/input/emojiimage-dataset/image/Gmail/564.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1332.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1024.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1042.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1363.png
# /kaggle/input/emojiimage-dataset/image/Gmail/15.png
# /kaggle/input/emojiimage-dataset/image/Gmail/210.png
# /kaggle/input/emojiimage-dataset/image/Gmail/234.png
# /kaggle/input/emojiimage-dataset/image/Gmail/652.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1397.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1251.png
# /kaggle/input/emojiimage-dataset/image/Gmail/822.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1331.png
# /kaggle/input/emojiimage-dataset/image/Gmail/183.png
# /kaggle/input/emojiimage-dataset/image/Gmail/893.png
# /kaggle/input/emojiimage-dataset/image/Gmail/631.png
# /kaggle/input/emojiimage-dataset/image/Gmail/708.png
# /kaggle/input/emojiimage-dataset/image/Gmail/919.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1177.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1392.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1491.png
# /kaggle/input/emojiimage-dataset/image/Gmail/60.png
# /kaggle/input/emojiimage-dataset/image/Gmail/235.png
# /kaggle/input/emojiimage-dataset/image/Gmail/765.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1671.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1141.png
# /kaggle/input/emojiimage-dataset/image/Gmail/27.png
# /kaggle/input/emojiimage-dataset/image/Gmail/999.png
# /kaggle/input/emojiimage-dataset/image/Gmail/539.png
# /kaggle/input/emojiimage-dataset/image/Gmail/519.png
# /kaggle/input/emojiimage-dataset/image/Gmail/845.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1395.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1058.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1336.png
# /kaggle/input/emojiimage-dataset/image/Gmail/47.png
# /kaggle/input/emojiimage-dataset/image/Gmail/207.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1487.png
# /kaggle/input/emojiimage-dataset/image/Gmail/812.png
# /kaggle/input/emojiimage-dataset/image/Gmail/842.png
# /kaggle/input/emojiimage-dataset/image/Gmail/535.png
# /kaggle/input/emojiimage-dataset/image/Gmail/843.png
# /kaggle/input/emojiimage-dataset/image/Gmail/830.png
# /kaggle/input/emojiimage-dataset/image/Gmail/206.png
# /kaggle/input/emojiimage-dataset/image/Gmail/789.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1365.png
# /kaggle/input/emojiimage-dataset/image/Gmail/557.png
# /kaggle/input/emojiimage-dataset/image/Gmail/980.png
# /kaggle/input/emojiimage-dataset/image/Gmail/613.png
# /kaggle/input/emojiimage-dataset/image/Gmail/346.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1497.png
# /kaggle/input/emojiimage-dataset/image/Gmail/134.png
# /kaggle/input/emojiimage-dataset/image/Gmail/721.png
# /kaggle/input/emojiimage-dataset/image/Gmail/694.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1172.png
# /kaggle/input/emojiimage-dataset/image/Gmail/566.png
# /kaggle/input/emojiimage-dataset/image/Gmail/25.png
# /kaggle/input/emojiimage-dataset/image/Gmail/851.png
# /kaggle/input/emojiimage-dataset/image/Gmail/558.png
# /kaggle/input/emojiimage-dataset/image/Gmail/111.png
# /kaggle/input/emojiimage-dataset/image/Gmail/611.png
# /kaggle/input/emojiimage-dataset/image/Gmail/887.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1373.png
# /kaggle/input/emojiimage-dataset/image/Gmail/699.png
# /kaggle/input/emojiimage-dataset/image/Gmail/750.png
# /kaggle/input/emojiimage-dataset/image/Gmail/693.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1408.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1211.png
# /kaggle/input/emojiimage-dataset/image/Gmail/19.png
# /kaggle/input/emojiimage-dataset/image/Gmail/110.png
# /kaggle/input/emojiimage-dataset/image/Gmail/544.png
# /kaggle/input/emojiimage-dataset/image/Gmail/918.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1453.png
# /kaggle/input/emojiimage-dataset/image/Gmail/79.png
# /kaggle/input/emojiimage-dataset/image/Gmail/633.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1396.png
# /kaggle/input/emojiimage-dataset/image/Gmail/729.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1477.png
# /kaggle/input/emojiimage-dataset/image/Gmail/883.png
# /kaggle/input/emojiimage-dataset/image/Gmail/257.png
# /kaggle/input/emojiimage-dataset/image/Gmail/993.png
# /kaggle/input/emojiimage-dataset/image/Gmail/175.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1261.png
# /kaggle/input/emojiimage-dataset/image/Gmail/518.png
# /kaggle/input/emojiimage-dataset/image/Gmail/957.png
# /kaggle/input/emojiimage-dataset/image/Gmail/1493.png
# /kaggle/input/emojiimage-dataset/image/Gmail/428.png
# /kaggle/input/emojiimage-dataset/image/Gmail/217.png
# /kaggle/input/emojiimage-dataset/image/Gmail/821.png
# /kaggle/input/emojiimage-dataset/image/Gmail/837.png
# /kaggle/input/emojiimage-dataset/image/Gmail/659.png
# /kaggle/input/emojiimage-dataset/image/Gmail/418.png
# /kaggle/input/emojiimage-dataset/image/Gmail/981.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
from tensorflow.keras import layers

# %%
df = pd.read_csv('/kaggle/input/emojiimage-dataset/full_emoji.csv')
df.head()
# Out:
#    # emoji  unicode                             name  \
# 0  1     😀  U+1F600                    grinning face
# 1  2     😃  U+1F603      grinning face with big eyes
# 2  3     😄  U+1F604  grinning face with smiling eyes
# 3  4     😁  U+1F601   beaming face with smiling eyes
# 4  5     😆  U+1F606          grinning squinting face
#
#                                                Apple  \
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......
#
#                                               Google  \
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......
#
#                                             Facebook  \
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......
#
#                                              Windows  \
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......
#
#                                              Twitter  \
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......
#
#                                            JoyPixels  \
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......
#
#                                              Samsung  \
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......
#
#                                                Gmail  \
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......
#
#                                             SoftBank  \
# 0                                                NaN
# 1  ......
# 2  ......
# 3  ......
# 4                                                NaN
#
#                                               DoCoMo  \
# 0                                                NaN
# 1  ......
# 2                                                NaN
# 3  ......
# 4  ......
#
#                                                 KDDI
# 0                                                NaN
# 1  ......
# 2                                                NaN
# 3  ......
# 4                                                NaN

# %%
import pathlib

data_dir = pathlib.Path("/kaggle/input/emojiimage-dataset/image/")

# %%
image_count = len(list(data_dir.glob('*/*.png')))
print(image_count)
# Out:
# 14253

# %%
batch_size = 32
img_height = 250
img_width = 250

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 14253 files belonging to 11 classes.
# 2022-05-06 17:51:18.111041: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Apple', 'DoCoMo', 'Facebook', 'Gmail', 'Google', 'JoyPixels', 'KDDI', 'Samsung', 'SoftBank', 'Twitter', 'Windows']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# 2022-05-06 17:51:18.489164: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
def make_generator_model():
    model = tf.keras.Sequential()
    model.add(layers.Dense(7*7*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((7, 7, 256)))
    assert model.output_shape == (None, 7, 7, 256)  # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 7, 7, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 14, 14, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    #assert model.output_shape == (None, 250, 250, 1)

    return model

# %%
generator = make_generator_model()

noise = tf.random.normal([1, 100])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0], cmap='gray')

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same',
                                     input_shape=[250, 250, 1]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1))

    return model

# %%
# discriminator = make_discriminator_model()
# decision = discriminator(generated_image)
# print (decision)

# %% [markdown]
# ## Use DCGAN to generate novel emojis

# %% [markdown]
# ## References
# * https://github.com/teddykoker/cryptopunks-gan
# * https://huggingface.co/nateraw/cryptopunks-gan
# * https://huggingface.co/spaces/huggan/huggingnft
# * https://www.tensorflow.org/tutorials/generative/dcgan#create_the_models
# * https://www.tensorflow.org/tutorials/load_data/images
